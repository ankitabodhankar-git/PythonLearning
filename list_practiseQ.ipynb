# %%
# print 1st and last element from list //always use index this typq ques.
num = [1, 2, 4, 6, 8, 14, 5, 7, 9]
print(nums[0])
print(nums[-1])
# Out:
# 1
# 9

# %%
# print all numbers  // use looop
num = [1, 2, 4, 6, 8, 14, 5, 7, 9]
for item in nums:
    print(item)
# Out:
# 1
# 2
# 4
# 6
# 8
# 14
# 5
# 7
# 9

# %%
# created empty list and add 3 values // add one by one using append() // use in cart,task
nums = []
nums.append(10)
nums.append(50)
nums.append(90)
print(nums)
# Out:
# [10, 50, 90]

# %%
# find largest number from list
lst = [10, 50, 90]
largest = lst[0]
for nums in lst :
   if  nums > largest:    #practise reapet
       largest = nums
print(largest)
# Out:
# 90

# %%
# count even number from list
lst = [10, 21, 4, 7, 8]
count = 0

for num in lst:
    if num % 2 == 0: #even
        count += 1
print(count)
# Out:
# 2

# %%
# print greater than 50 numbers from list
lst = [10, 55, 60, 30, 80]

for num in lst:
    if num > 50:
        print(num, end =" ")
# Out:
# 55 60 80

# %%
marks = [35, 60, 80, 25, 45]
for m in marks:
    if m >= 40:
        print(m, end = " ")
# Out:
# 60 80 45

# %%
prices = [500, 300, 200]
total = 0

for p in prices:
    total += p

print(total)
# Out:
# 1000
