# %%
print("Hello Word")
# Out:
# Hello Word

# %%
a= "hello" 
n=5 
print(a * n)
# Out:
# hellohellohellohellohello

# %%
a= int(input("enter 1st number:")),
b= int(input("enter 2nd number:")),
c = int(input("enter 3rd number:"))

print("greatest number" , a or b or c )
# Out:
# enter 1st number: 9
# enter 2nd number: 7
# enter 3rd number: 1
# greatest number (9,)

# %%
a = int(input("enter ur marks"))
if a>=90:
    print("very good")
elif a>=50:
    print(" average")
elif a<= 35:
    print("poor")
else:
    print("fail")
# Out:
# enter ur marks 66
#  average

# %%
a= "6"
b= "4"
c= "&"
print(a*6 ,c*1, b*4 )
# Out:
# 666666 & 4444

# %%
correct_username = "ankita"
correct_password = "1234"
username =input("enter ur username:")
password =input("enter ur password:")
if username == correct_username and password == correct_password:
    print("login sucessfull")
else:
    print("invalid username or password")
# Out:
# enter ur username: ankita
# enter ur password: 1234
# login sucessfull

# %%
a = int(input("enter 1st number:"),
b = int(input("enter 2nd number:")
op = input("enter operation(+, -, *, /, %)")

if op == "+":
   print("addition of a and b", a+b)
elif op== "-":
   print("substraction of a and b", a-b)
elif op == "*":
    print("multiplication of a and b", a*b)
elif op == "/"

# %%
a = int(input("enter ur number:"))

if a % 2== 0 and a % 2==1:
    print("even")
else: 
    print("odd")
# Out:
# enter ur number: 4
# odd
