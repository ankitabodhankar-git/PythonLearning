# %%
# FILE HANDLING , means read data from a file or writing data into fileusinh py.
# used to store data eg. loginsystem,students maarks,report,bills,etcc
# types text files-use(.txt) and binary file- img,pdf
file = open("data.txt" , "w")  #w use for create file if not existed
file.write("hello python\n")
file.close()

# reads only one line
file = open("data.txt" , "r")  
print(file.readline())
file.close()

# reads all line at a time
file = open("data.txt", "r")
lines = file.readlines()
print(lines)
file.close()

# Append Mode ("a") 
# Example Add data without deleting old data
file = open("data.txt", "a")
file.write("\nNew line added")
file.close()

# with open() (BEST PRACTICE) Instead of manually closing file:
with open("data.txt", "r") as file:
    print(file.read())

# Examples
with open("marks.txt", "a") as file:
    name = input("Enter name: ")
    marks = input("Enter marks: ")
    file.write(f"{name} - {marks}\n")

# searching data in files
with open("marks.txt","r") as file:
    for line in files:
        if "ankita" in line:
            print(line)
# Out:
# hello python
#
# ['hello python\n']
# hello python
#
# New line added
# Enter name:  tanuja
# Enter marks:  56
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 37
#      35 # searching data in files
#      36 with open("marks.txt","r") as file:
# ---> 37     for line in files:
#      38         if "ankita" in line:
#      39             print(line)
#
# NameError: name 'files' is not defined
