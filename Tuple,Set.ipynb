# %%
# tuple = Tuple is like a list that cannot be changed. / use () brackets use when u ipdated data
# its mutable ,duplicated allow
t = (10,20,30,40)
print(t)
days = ("Mon", "Tue", "Wed", "Thu", "Fri")
print(days)
# Out:
# (10, 20, 30, 40)
# ('Mon', 'Tue', 'Wed', 'Thu', 'Fri')

# %%
# operations 
# access elements
t = (10, 20, 30)
print(t[1])
# Out:
# 20

# %%
# tuples useing loop
t = (10, 20, 80)
for x in t:
    print(x)
# Out:
# 10
# 20
# 80

# %%
# concatenation
t1 = (1, 2)
t2 = (3, 4)
print(t1 + t2)
# Out:
# (1, 2, 3, 4)

# %%
# repitation
print((5, 6) * 3)
# Out:
# (5, 6, 5, 6, 5, 6)

# %%
# membership
print(20 in t)
# Out:
# True

# %%
# Methods
# count
t = (1,2,2,3,6,2)
print(t.count(2))
# Out:
# 3

# %%
# index its find position specific no.
t = (1,2,2,3,6,2)
print(t.index(2))
# Out:
# 1

# %%
# SET- Set stores unique values only, no duplicates, no order
# reallife use in uniques id, email, product ids, tag etc,..
s= {10,20,30}
print(s)
# Out:
# {10, 20, 30}

# %%
# Operations
# add elememts
s = {1, 2}
s.add(3.64)
print(s)
# Out:
# {1, 2, 3.64}

# %%
# loop
s = {1, 2}
for x in s:
    print(x)
# Out:
# 1
# 2

# %%
# Intersection
A = {1,2,3,6,8}
B = {3,4,5,8,9}
print(A & B)
print(A|B)  #UNION
print(A - B)  #diffrence
print(A ^ B)   #symmetrric diff
# Out:
# {8, 3}
# {1, 2, 3, 4, 5, 6, 8, 9}
# {1, 2, 6}
# {1, 2, 4, 5, 6, 9}
