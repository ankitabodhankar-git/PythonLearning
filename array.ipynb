# %%
# ARRAY //Python array comes from a module called array  uses sensor reading,img pixels,large data
# creating array syntax  //array(typecode, values)
from array import array
arr = array('i', [10, 20, 30, 40])
print(arr)
# Out:
# array('i', [10, 20, 30, 40])

# %%
# ARRAY OPERATIONS
# acces elements
arr = array('i', [10, 20, 30, 40])
print(arr[0])
# Out:
# 10

# %%
# loop throught array
arr = [10, 20, 30, 40]
for x in arr:
    print(x)
# Out:
# 10
# 20
# 30
# 40

# %%
arr = [10, 20, 30, 40]
arr.append(50)
print(arr)
arr.remove(20)
print(arr)
print(len(arr))
# Out:
# [10, 20, 30, 40, 50]
# [10, 30, 40, 50]
# 4
